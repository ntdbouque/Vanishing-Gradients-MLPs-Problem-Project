# %% [markdown]
# ## Load Data

# %%
import torch 
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
import numpy as np 

torch.manual_seed(42)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
batch_size = 512
num_epochs = 300
lr = 0.01

# %%
train_dataset = FashionMNIST('./data', train=True, download=True, transform=transforms.ToTensor())
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
test_dataset = FashionMNIST('./data', train=False, download=True, transform=transforms.ToTensor())
test_loader = DataLoader(test_dataset, batch_size)

# %% [markdown]
# ## Better Optimizer

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.05)
                nn.init.constant_(m.bias, 0.0)
                

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.layer1(x)
        x = nn.Sigmoid()(x)
        x = self.layer2(x)
        x = nn.Sigmoid()(x)
        x = self.layer3(x)
        x = nn.Sigmoid()(x)
        x = self.layer4(x)
        x = nn.Sigmoid()(x)
        x = self.layer5(x)
        x = nn.Sigmoid()(x)
        x = self.layer6(x)
        x = nn.Sigmoid()(x)
        x = self.layer7(x)
        x = nn.Sigmoid()(x)
        out = self.output(x)

        return out

# %%
model = MLP(input_dims=784, hidden_dims=128, output_dims=10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_losses = []
train_acc = []
val_losses = []
val_acc = []

for epoch in range(num_epochs):
    model.train()
    t_loss = 0
    t_acc = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        t_loss += loss.item()
        t_acc += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    t_loss /= len(train_loader)
    train_losses.append(t_loss)
    t_acc /= cnt
    train_acc.append(t_acc)

    model.eval()
    v_loss = 0
    v_acc = 0
    cnt = 0
    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            v_loss += loss.item()
            v_acc += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    v_loss /= len(test_loader)
    val_losses.append(v_loss)
    v_acc /= cnt
    val_acc.append(v_acc)
    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {t_loss:.4f}, Train_Acc: {t_acc:.4f}, Validation Loss: {v_loss:.4f}, Val_Acc: {v_acc:.4f}")
# Out:
# Epoch 1/300, Train_Loss: 2.1292, Train_Acc: 0.1451, Validation Loss: 1.7021, Val_Acc: 0.1995
# Epoch 2/300, Train_Loss: 1.6980, Train_Acc: 0.1982, Validation Loss: 1.6927, Val_Acc: 0.1993
# Epoch 3/300, Train_Loss: 1.6862, Train_Acc: 0.1971, Validation Loss: 1.6876, Val_Acc: 0.1989
# Epoch 4/300, Train_Loss: 1.6811, Train_Acc: 0.1998, Validation Loss: 1.6843, Val_Acc: 0.2000
# Epoch 5/300, Train_Loss: 1.6742, Train_Acc: 0.2054, Validation Loss: 1.6609, Val_Acc: 0.2078
# Epoch 6/300, Train_Loss: 1.5105, Train_Acc: 0.2954, Validation Loss: 1.4258, Val_Acc: 0.3595
# Epoch 7/300, Train_Loss: 1.2692, Train_Acc: 0.4478, Validation Loss: 1.0841, Val_Acc: 0.5480
# Epoch 8/300, Train_Loss: 0.9431, Train_Acc: 0.6213, Validation Loss: 0.8514, Val_Acc: 0.6482
# Epoch 9/300, Train_Loss: 0.7841, Train_Acc: 0.6975, Validation Loss: 0.7495, Val_Acc: 0.7450
# Epoch 10/300, Train_Loss: 0.7096, Train_Acc: 0.7477, Validation Loss: 0.6877, Val_Acc: 0.7705
# Epoch 11/300, Train_Loss: 0.6456, Train_Acc: 0.7779, Validation Loss: 0.6675, Val_Acc: 0.7699
# Epoch 12/300, Train_Loss: 0.6112, Train_Acc: 0.7870, Validation Loss: 0.6145, Val_Acc: 0.7850
# Epoch 13/300, Train_Loss: 0.5798, Train_Acc: 0.7989, Validation Loss: 0.5973, Val_Acc: 0.7925
# Epoch 14/300, Train_Loss: 0.5615, Train_Acc: 0.8046, Validation Loss: 0.5946, Val_Acc: 0.7936
# Epoch 15/300, Train_Loss: 0.5461, Train_Acc: 0.8111, Validation Loss: 0.5958, Val_Acc: 0.7907
# Epoch 16/300, Train_Loss: 0.5338, Train_Acc: 0.8165, Validation Loss: 0.5788, Val_Acc: 0.8010
# Epoch 17/300, Train_Loss: 0.5222, Train_Acc: 0.8224, Validation Loss: 0.5746, Val_Acc: 0.7993
# Epoch 18/300, Train_Loss: 0.5092, Train_Acc: 0.8279, Validation Loss: 0.5612, Val_Acc: 0.8080
# Epoch 19/300, Train_Loss: 0.4958, Train_Acc: 0.8358, Validation Loss: 0.5569, Val_Acc: 0.8184
# Epoch 20/300, Train_Loss: 0.4868, Train_Acc: 0.8400, Validation Loss: 0.5496, Val_Acc: 0.8180
# Epoch 21/300, Train_Loss: 0.4812, Train_Acc: 0.8412, Validation Loss: 0.5572, Val_Acc: 0.8186
# Epoch 22/300, Train_Loss: 0.4805, Train_Acc: 0.8408, Validation Loss: 0.5528, Val_Acc: 0.8160
# Epoch 23/300, Train_Loss: 0.4634, Train_Acc: 0.8478, Validation Loss: 0.5370, Val_Acc: 0.8233
# Epoch 24/300, Train_Loss: 0.4579, Train_Acc: 0.8508, Validation Loss: 0.5466, Val_Acc: 0.8203
# Epoch 25/300, Train_Loss: 0.4553, Train_Acc: 0.8514, Validation Loss: 0.5771, Val_Acc: 0.8069
# Epoch 26/300, Train_Loss: 0.4457, Train_Acc: 0.8570, Validation Loss: 0.5280, Val_Acc: 0.8283
# Epoch 27/300, Train_Loss: 0.4420, Train_Acc: 0.8562, Validation Loss: 0.5545, Val_Acc: 0.8135
# Epoch 28/300, Train_Loss: 0.4362, Train_Acc: 0.8587, Validation Loss: 0.5232, Val_Acc: 0.8262
# Epoch 29/300, Train_Loss: 0.4339, Train_Acc: 0.8612, Validation Loss: 0.5174, Val_Acc: 0.8316
# Epoch 30/300, Train_Loss: 0.4213, Train_Acc: 0.8656, Validation Loss: 0.5702, Val_Acc: 0.8059
# Epoch 31/300, Train_Loss: 0.4269, Train_Acc: 0.8621, Validation Loss: 0.5223, Val_Acc: 0.8288
# Epoch 32/300, Train_Loss: 0.4207, Train_Acc: 0.8652, Validation Loss: 0.5121, Val_Acc: 0.8333
# Epoch 33/300, Train_Loss: 0.4130, Train_Acc: 0.8681, Validation Loss: 0.5108, Val_Acc: 0.8336
# Epoch 34/300, Train_Loss: 0.4053, Train_Acc: 0.8713, Validation Loss: 0.5231, Val_Acc: 0.8306
# Epoch 35/300, Train_Loss: 0.4032, Train_Acc: 0.8720, Validation Loss: 0.5156, Val_Acc: 0.8349
# Epoch 36/300, Train_Loss: 0.3946, Train_Acc: 0.8757, Validation Loss: 0.5222, Val_Acc: 0.8311
# Epoch 37/300, Train_Loss: 0.3951, Train_Acc: 0.8749, Validation Loss: 0.5182, Val_Acc: 0.8313
# Epoch 38/300, Train_Loss: 0.4029, Train_Acc: 0.8705, Validation Loss: 0.5091, Val_Acc: 0.8351
# Epoch 39/300, Train_Loss: 0.3882, Train_Acc: 0.8787, Validation Loss: 0.5175, Val_Acc: 0.8321
# Epoch 40/300, Train_Loss: 0.3842, Train_Acc: 0.8787, Validation Loss: 0.5060, Val_Acc: 0.8398
# Epoch 41/300, Train_Loss: 0.3814, Train_Acc: 0.8811, Validation Loss: 0.5084, Val_Acc: 0.8369
# Epoch 42/300, Train_Loss: 0.3754, Train_Acc: 0.8832, Validation Loss: 0.5087, Val_Acc: 0.8389
# Epoch 43/300, Train_Loss: 0.3825, Train_Acc: 0.8793, Validation Loss: 0.5269, Val_Acc: 0.8264
# Epoch 44/300, Train_Loss: 0.3764, Train_Acc: 0.8814, Validation Loss: 0.5046, Val_Acc: 0.8413
# Epoch 45/300, Train_Loss: 0.3672, Train_Acc: 0.8856, Validation Loss: 0.5121, Val_Acc: 0.8380
# Epoch 46/300, Train_Loss: 0.3661, Train_Acc: 0.8849, Validation Loss: 0.5048, Val_Acc: 0.8419
# Epoch 47/300, Train_Loss: 0.3635, Train_Acc: 0.8865, Validation Loss: 0.5072, Val_Acc: 0.8408
# Epoch 48/300, Train_Loss: 0.3630, Train_Acc: 0.8863, Validation Loss: 0.5157, Val_Acc: 0.8365
# Epoch 49/300, Train_Loss: 0.3698, Train_Acc: 0.8836, Validation Loss: 0.5158, Val_Acc: 0.8379
# Epoch 50/300, Train_Loss: 0.3578, Train_Acc: 0.8888, Validation Loss: 0.5263, Val_Acc: 0.8317
# Epoch 51/300, Train_Loss: 0.3557, Train_Acc: 0.8894, Validation Loss: 0.5082, Val_Acc: 0.8418
# Epoch 52/300, Train_Loss: 0.3515, Train_Acc: 0.8907, Validation Loss: 0.5075, Val_Acc: 0.8422
# Epoch 53/300, Train_Loss: 0.3489, Train_Acc: 0.8931, Validation Loss: 0.5161, Val_Acc: 0.8383
# Epoch 54/300, Train_Loss: 0.3456, Train_Acc: 0.8920, Validation Loss: 0.5046, Val_Acc: 0.8424
# Epoch 55/300, Train_Loss: 0.3423, Train_Acc: 0.8953, Validation Loss: 0.5299, Val_Acc: 0.8312
# Epoch 56/300, Train_Loss: 0.3474, Train_Acc: 0.8920, Validation Loss: 0.5013, Val_Acc: 0.8442
# Epoch 57/300, Train_Loss: 0.3362, Train_Acc: 0.8975, Validation Loss: 0.5099, Val_Acc: 0.8419
# Epoch 58/300, Train_Loss: 0.3428, Train_Acc: 0.8939, Validation Loss: 0.5121, Val_Acc: 0.8427
# Epoch 59/300, Train_Loss: 0.3426, Train_Acc: 0.8944, Validation Loss: 0.5099, Val_Acc: 0.8392
# Epoch 60/300, Train_Loss: 0.3350, Train_Acc: 0.8975, Validation Loss: 0.5055, Val_Acc: 0.8430
# Epoch 61/300, Train_Loss: 0.3396, Train_Acc: 0.8942, Validation Loss: 0.5200, Val_Acc: 0.8392
# Epoch 62/300, Train_Loss: 0.3264, Train_Acc: 0.9015, Validation Loss: 0.5192, Val_Acc: 0.8368
# Epoch 63/300, Train_Loss: 0.3347, Train_Acc: 0.8966, Validation Loss: 0.5151, Val_Acc: 0.8397
# Epoch 64/300, Train_Loss: 0.3227, Train_Acc: 0.9014, Validation Loss: 0.5095, Val_Acc: 0.8441
# Epoch 65/300, Train_Loss: 0.3248, Train_Acc: 0.9005, Validation Loss: 0.5238, Val_Acc: 0.8353
# Epoch 66/300, Train_Loss: 0.3251, Train_Acc: 0.9000, Validation Loss: 0.5163, Val_Acc: 0.8384
# Epoch 67/300, Train_Loss: 0.3152, Train_Acc: 0.9047, Validation Loss: 0.5117, Val_Acc: 0.8399
# Epoch 68/300, Train_Loss: 0.3191, Train_Acc: 0.9016, Validation Loss: 0.5069, Val_Acc: 0.8439
# Epoch 69/300, Train_Loss: 0.3076, Train_Acc: 0.9067, Validation Loss: 0.5038, Val_Acc: 0.8462
# Epoch 70/300, Train_Loss: 0.3028, Train_Acc: 0.9090, Validation Loss: 0.5037, Val_Acc: 0.8421
# Epoch 71/300, Train_Loss: 0.2976, Train_Acc: 0.9099, Validation Loss: 0.5219, Val_Acc: 0.8343
# Epoch 72/300, Train_Loss: 0.2987, Train_Acc: 0.9085, Validation Loss: 0.4878, Val_Acc: 0.8472
# Epoch 73/300, Train_Loss: 0.2874, Train_Acc: 0.9121, Validation Loss: 0.4948, Val_Acc: 0.8478
# Epoch 74/300, Train_Loss: 0.2829, Train_Acc: 0.9141, Validation Loss: 0.5160, Val_Acc: 0.8339
# Epoch 75/300, Train_Loss: 0.2950, Train_Acc: 0.9076, Validation Loss: 0.5505, Val_Acc: 0.8268
# Epoch 76/300, Train_Loss: 0.2857, Train_Acc: 0.9123, Validation Loss: 0.4769, Val_Acc: 0.8514
# Epoch 77/300, Train_Loss: 0.2804, Train_Acc: 0.9137, Validation Loss: 0.4734, Val_Acc: 0.8550
# Epoch 78/300, Train_Loss: 0.2799, Train_Acc: 0.9133, Validation Loss: 0.4698, Val_Acc: 0.8571
# Epoch 79/300, Train_Loss: 0.2690, Train_Acc: 0.9180, Validation Loss: 0.4901, Val_Acc: 0.8470
# Epoch 80/300, Train_Loss: 0.2647, Train_Acc: 0.9195, Validation Loss: 0.4822, Val_Acc: 0.8471
# Epoch 81/300, Train_Loss: 0.2618, Train_Acc: 0.9197, Validation Loss: 0.4737, Val_Acc: 0.8536
# Epoch 82/300, Train_Loss: 0.2619, Train_Acc: 0.9198, Validation Loss: 0.4703, Val_Acc: 0.8569
# Epoch 83/300, Train_Loss: 0.2589, Train_Acc: 0.9210, Validation Loss: 0.4710, Val_Acc: 0.8544
# Epoch 84/300, Train_Loss: 0.2562, Train_Acc: 0.9211, Validation Loss: 0.4977, Val_Acc: 0.8483
# Epoch 85/300, Train_Loss: 0.2549, Train_Acc: 0.9216, Validation Loss: 0.4654, Val_Acc: 0.8582
# Epoch 86/300, Train_Loss: 0.2545, Train_Acc: 0.9215, Validation Loss: 0.4816, Val_Acc: 0.8516
# Epoch 87/300, Train_Loss: 0.2521, Train_Acc: 0.9219, Validation Loss: 0.4638, Val_Acc: 0.8577
# Epoch 88/300, Train_Loss: 0.2471, Train_Acc: 0.9231, Validation Loss: 0.4754, Val_Acc: 0.8540
# Epoch 89/300, Train_Loss: 0.2471, Train_Acc: 0.9237, Validation Loss: 0.4702, Val_Acc: 0.8606
# Epoch 90/300, Train_Loss: 0.2412, Train_Acc: 0.9267, Validation Loss: 0.4687, Val_Acc: 0.8601
# Epoch 91/300, Train_Loss: 0.2408, Train_Acc: 0.9264, Validation Loss: 0.4686, Val_Acc: 0.8573
# Epoch 92/300, Train_Loss: 0.2385, Train_Acc: 0.9263, Validation Loss: 0.4938, Val_Acc: 0.8486
# Epoch 93/300, Train_Loss: 0.2414, Train_Acc: 0.9256, Validation Loss: 0.4608, Val_Acc: 0.8631
# Epoch 94/300, Train_Loss: 0.2435, Train_Acc: 0.9254, Validation Loss: 0.4838, Val_Acc: 0.8552
# Epoch 95/300, Train_Loss: 0.2310, Train_Acc: 0.9293, Validation Loss: 0.4762, Val_Acc: 0.8571
# Epoch 96/300, Train_Loss: 0.2337, Train_Acc: 0.9282, Validation Loss: 0.4662, Val_Acc: 0.8572
# Epoch 97/300, Train_Loss: 0.2261, Train_Acc: 0.9314, Validation Loss: 0.4918, Val_Acc: 0.8552
# Epoch 98/300, Train_Loss: 0.2442, Train_Acc: 0.9240, Validation Loss: 0.4651, Val_Acc: 0.8603
# Epoch 99/300, Train_Loss: 0.2296, Train_Acc: 0.9291, Validation Loss: 0.4657, Val_Acc: 0.8599
# Epoch 100/300, Train_Loss: 0.2227, Train_Acc: 0.9319, Validation Loss: 0.4811, Val_Acc: 0.8574
# Epoch 101/300, Train_Loss: 0.2240, Train_Acc: 0.9312, Validation Loss: 0.4795, Val_Acc: 0.8588
# Epoch 102/300, Train_Loss: 0.2228, Train_Acc: 0.9320, Validation Loss: 0.5066, Val_Acc: 0.8459
# Epoch 103/300, Train_Loss: 0.2299, Train_Acc: 0.9284, Validation Loss: 0.4848, Val_Acc: 0.8490
# Epoch 104/300, Train_Loss: 0.2228, Train_Acc: 0.9310, Validation Loss: 0.4629, Val_Acc: 0.8606
# Epoch 105/300, Train_Loss: 0.2146, Train_Acc: 0.9354, Validation Loss: 0.4704, Val_Acc: 0.8603
# Epoch 106/300, Train_Loss: 0.2140, Train_Acc: 0.9354, Validation Loss: 0.4837, Val_Acc: 0.8595
# Epoch 107/300, Train_Loss: 0.2156, Train_Acc: 0.9342, Validation Loss: 0.4794, Val_Acc: 0.8581
# Epoch 108/300, Train_Loss: 0.2139, Train_Acc: 0.9343, Validation Loss: 0.4736, Val_Acc: 0.8612
# Epoch 109/300, Train_Loss: 0.2169, Train_Acc: 0.9333, Validation Loss: 0.4815, Val_Acc: 0.8605
# Epoch 110/300, Train_Loss: 0.2117, Train_Acc: 0.9356, Validation Loss: 0.4957, Val_Acc: 0.8540
# Epoch 111/300, Train_Loss: 0.2230, Train_Acc: 0.9310, Validation Loss: 0.4735, Val_Acc: 0.8627
# Epoch 112/300, Train_Loss: 0.2115, Train_Acc: 0.9363, Validation Loss: 0.5009, Val_Acc: 0.8484
# Epoch 113/300, Train_Loss: 0.2073, Train_Acc: 0.9374, Validation Loss: 0.4990, Val_Acc: 0.8503
# Epoch 114/300, Train_Loss: 0.2020, Train_Acc: 0.9393, Validation Loss: 0.4734, Val_Acc: 0.8632
# Epoch 115/300, Train_Loss: 0.2001, Train_Acc: 0.9399, Validation Loss: 0.4829, Val_Acc: 0.8604
# Epoch 116/300, Train_Loss: 0.2162, Train_Acc: 0.9342, Validation Loss: 0.4685, Val_Acc: 0.8620
# Epoch 117/300, Train_Loss: 0.2053, Train_Acc: 0.9381, Validation Loss: 0.4741, Val_Acc: 0.8619
# Epoch 118/300, Train_Loss: 0.2016, Train_Acc: 0.9384, Validation Loss: 0.5305, Val_Acc: 0.8518
# Epoch 119/300, Train_Loss: 0.2081, Train_Acc: 0.9358, Validation Loss: 0.5103, Val_Acc: 0.8487
# Epoch 120/300, Train_Loss: 0.1968, Train_Acc: 0.9406, Validation Loss: 0.4820, Val_Acc: 0.8624
# Epoch 121/300, Train_Loss: 0.1920, Train_Acc: 0.9412, Validation Loss: 0.4914, Val_Acc: 0.8571
# Epoch 122/300, Train_Loss: 0.1963, Train_Acc: 0.9402, Validation Loss: 0.4820, Val_Acc: 0.8637
# Epoch 123/300, Train_Loss: 0.1940, Train_Acc: 0.9404, Validation Loss: 0.4974, Val_Acc: 0.8572
# Epoch 124/300, Train_Loss: 0.1925, Train_Acc: 0.9419, Validation Loss: 0.5088, Val_Acc: 0.8604
# Epoch 125/300, Train_Loss: 0.1898, Train_Acc: 0.9429, Validation Loss: 0.4885, Val_Acc: 0.8627
# Epoch 126/300, Train_Loss: 0.1877, Train_Acc: 0.9436, Validation Loss: 0.4936, Val_Acc: 0.8616
# Epoch 127/300, Train_Loss: 0.1932, Train_Acc: 0.9409, Validation Loss: 0.5180, Val_Acc: 0.8519
# Epoch 128/300, Train_Loss: 0.1889, Train_Acc: 0.9425, Validation Loss: 0.4950, Val_Acc: 0.8629
# Epoch 129/300, Train_Loss: 0.1866, Train_Acc: 0.9437, Validation Loss: 0.5412, Val_Acc: 0.8541
# Epoch 130/300, Train_Loss: 0.1874, Train_Acc: 0.9438, Validation Loss: 0.5040, Val_Acc: 0.8573
# Epoch 131/300, Train_Loss: 0.1873, Train_Acc: 0.9433, Validation Loss: 0.5087, Val_Acc: 0.8597
# Epoch 132/300, Train_Loss: 0.1876, Train_Acc: 0.9431, Validation Loss: 0.4931, Val_Acc: 0.8622
# Epoch 133/300, Train_Loss: 0.1846, Train_Acc: 0.9439, Validation Loss: 0.5059, Val_Acc: 0.8552
# Epoch 134/300, Train_Loss: 0.1938, Train_Acc: 0.9406, Validation Loss: 0.5100, Val_Acc: 0.8567
# Epoch 135/300, Train_Loss: 0.1789, Train_Acc: 0.9462, Validation Loss: 0.4987, Val_Acc: 0.8624
# Epoch 136/300, Train_Loss: 0.1787, Train_Acc: 0.9457, Validation Loss: 0.5218, Val_Acc: 0.8552
# Epoch 137/300, Train_Loss: 0.1881, Train_Acc: 0.9417, Validation Loss: 0.5125, Val_Acc: 0.8539
# Epoch 138/300, Train_Loss: 0.1797, Train_Acc: 0.9459, Validation Loss: 0.4990, Val_Acc: 0.8635
# Epoch 139/300, Train_Loss: 0.1784, Train_Acc: 0.9466, Validation Loss: 0.5062, Val_Acc: 0.8609
# Epoch 140/300, Train_Loss: 0.1736, Train_Acc: 0.9478, Validation Loss: 0.5221, Val_Acc: 0.8606
# Epoch 141/300, Train_Loss: 0.1775, Train_Acc: 0.9459, Validation Loss: 0.5015, Val_Acc: 0.8629
# Epoch 142/300, Train_Loss: 0.1780, Train_Acc: 0.9459, Validation Loss: 0.5094, Val_Acc: 0.8600
# Epoch 143/300, Train_Loss: 0.1715, Train_Acc: 0.9486, Validation Loss: 0.4962, Val_Acc: 0.8665
# Epoch 144/300, Train_Loss: 0.1797, Train_Acc: 0.9457, Validation Loss: 0.5236, Val_Acc: 0.8554
# Epoch 145/300, Train_Loss: 0.1657, Train_Acc: 0.9503, Validation Loss: 0.5146, Val_Acc: 0.8602
# Epoch 146/300, Train_Loss: 0.1776, Train_Acc: 0.9460, Validation Loss: 0.5154, Val_Acc: 0.8649
# Epoch 147/300, Train_Loss: 0.1693, Train_Acc: 0.9488, Validation Loss: 0.5449, Val_Acc: 0.8515
# Epoch 148/300, Train_Loss: 0.1713, Train_Acc: 0.9483, Validation Loss: 0.5265, Val_Acc: 0.8621
# Epoch 149/300, Train_Loss: 0.1694, Train_Acc: 0.9492, Validation Loss: 0.5190, Val_Acc: 0.8583
# Epoch 150/300, Train_Loss: 0.1627, Train_Acc: 0.9509, Validation Loss: 0.5200, Val_Acc: 0.8621
# Epoch 151/300, Train_Loss: 0.1644, Train_Acc: 0.9503, Validation Loss: 0.5391, Val_Acc: 0.8551
# Epoch 152/300, Train_Loss: 0.1690, Train_Acc: 0.9495, Validation Loss: 0.5259, Val_Acc: 0.8554
# Epoch 153/300, Train_Loss: 0.1609, Train_Acc: 0.9514, Validation Loss: 0.5330, Val_Acc: 0.8570
# Epoch 154/300, Train_Loss: 0.1637, Train_Acc: 0.9508, Validation Loss: 0.5252, Val_Acc: 0.8620
# Epoch 155/300, Train_Loss: 0.1703, Train_Acc: 0.9487, Validation Loss: 0.5288, Val_Acc: 0.8626
# Epoch 156/300, Train_Loss: 0.1638, Train_Acc: 0.9510, Validation Loss: 0.5233, Val_Acc: 0.8584
# Epoch 157/300, Train_Loss: 0.1647, Train_Acc: 0.9509, Validation Loss: 0.5192, Val_Acc: 0.8596
# Epoch 158/300, Train_Loss: 0.1629, Train_Acc: 0.9506, Validation Loss: 0.5185, Val_Acc: 0.8627
# Epoch 159/300, Train_Loss: 0.1566, Train_Acc: 0.9535, Validation Loss: 0.5255, Val_Acc: 0.8614
# Epoch 160/300, Train_Loss: 0.1585, Train_Acc: 0.9521, Validation Loss: 0.5215, Val_Acc: 0.8593
# Epoch 161/300, Train_Loss: 0.1718, Train_Acc: 0.9480, Validation Loss: 0.5346, Val_Acc: 0.8564
# Epoch 162/300, Train_Loss: 0.1546, Train_Acc: 0.9542, Validation Loss: 0.5239, Val_Acc: 0.8628
# Epoch 163/300, Train_Loss: 0.1529, Train_Acc: 0.9543, Validation Loss: 0.5404, Val_Acc: 0.8600
# Epoch 164/300, Train_Loss: 0.1570, Train_Acc: 0.9527, Validation Loss: 0.5266, Val_Acc: 0.8599
# Epoch 165/300, Train_Loss: 0.1601, Train_Acc: 0.9519, Validation Loss: 0.5409, Val_Acc: 0.8588
# Epoch 166/300, Train_Loss: 0.1642, Train_Acc: 0.9506, Validation Loss: 0.5327, Val_Acc: 0.8569
# Epoch 167/300, Train_Loss: 0.1558, Train_Acc: 0.9534, Validation Loss: 0.5353, Val_Acc: 0.8626
# Epoch 168/300, Train_Loss: 0.1626, Train_Acc: 0.9498, Validation Loss: 0.5149, Val_Acc: 0.8659
# Epoch 169/300, Train_Loss: 0.1489, Train_Acc: 0.9559, Validation Loss: 0.5613, Val_Acc: 0.8533
# Epoch 170/300, Train_Loss: 0.1540, Train_Acc: 0.9542, Validation Loss: 0.5410, Val_Acc: 0.8640
# Epoch 171/300, Train_Loss: 0.1525, Train_Acc: 0.9549, Validation Loss: 0.6129, Val_Acc: 0.8415
# Epoch 172/300, Train_Loss: 0.1561, Train_Acc: 0.9537, Validation Loss: 0.5870, Val_Acc: 0.8461
# Epoch 173/300, Train_Loss: 0.1526, Train_Acc: 0.9538, Validation Loss: 0.5305, Val_Acc: 0.8639
# Epoch 174/300, Train_Loss: 0.1449, Train_Acc: 0.9564, Validation Loss: 0.5386, Val_Acc: 0.8622
# Epoch 175/300, Train_Loss: 0.1446, Train_Acc: 0.9576, Validation Loss: 0.5353, Val_Acc: 0.8625
# Epoch 176/300, Train_Loss: 0.1412, Train_Acc: 0.9575, Validation Loss: 0.5323, Val_Acc: 0.8615
# Epoch 177/300, Train_Loss: 0.1472, Train_Acc: 0.9560, Validation Loss: 0.5348, Val_Acc: 0.8637
# Epoch 178/300, Train_Loss: 0.1461, Train_Acc: 0.9567, Validation Loss: 0.5665, Val_Acc: 0.8586
# Epoch 179/300, Train_Loss: 0.1525, Train_Acc: 0.9545, Validation Loss: 0.5354, Val_Acc: 0.8616
# Epoch 180/300, Train_Loss: 0.1422, Train_Acc: 0.9577, Validation Loss: 0.5446, Val_Acc: 0.8586
# Epoch 181/300, Train_Loss: 0.1443, Train_Acc: 0.9570, Validation Loss: 0.5362, Val_Acc: 0.8589
# Epoch 182/300, Train_Loss: 0.1401, Train_Acc: 0.9586, Validation Loss: 0.5545, Val_Acc: 0.8576
# Epoch 183/300, Train_Loss: 0.1448, Train_Acc: 0.9570, Validation Loss: 0.5536, Val_Acc: 0.8628
# Epoch 184/300, Train_Loss: 0.1384, Train_Acc: 0.9590, Validation Loss: 0.5374, Val_Acc: 0.8621
# Epoch 185/300, Train_Loss: 0.1409, Train_Acc: 0.9578, Validation Loss: 0.5664, Val_Acc: 0.8563
# Epoch 186/300, Train_Loss: 0.1392, Train_Acc: 0.9586, Validation Loss: 0.5660, Val_Acc: 0.8554
# Epoch 187/300, Train_Loss: 0.1357, Train_Acc: 0.9599, Validation Loss: 0.5513, Val_Acc: 0.8636
# Epoch 188/300, Train_Loss: 0.1383, Train_Acc: 0.9596, Validation Loss: 0.5555, Val_Acc: 0.8605
# Epoch 189/300, Train_Loss: 0.1360, Train_Acc: 0.9603, Validation Loss: 0.5701, Val_Acc: 0.8592
# Epoch 190/300, Train_Loss: 0.1369, Train_Acc: 0.9591, Validation Loss: 0.5626, Val_Acc: 0.8581
# Epoch 191/300, Train_Loss: 0.1411, Train_Acc: 0.9577, Validation Loss: 0.5563, Val_Acc: 0.8614
# Epoch 192/300, Train_Loss: 0.1387, Train_Acc: 0.9586, Validation Loss: 0.5590, Val_Acc: 0.8605
# Epoch 193/300, Train_Loss: 0.1375, Train_Acc: 0.9584, Validation Loss: 0.5871, Val_Acc: 0.8557
# Epoch 194/300, Train_Loss: 0.1353, Train_Acc: 0.9596, Validation Loss: 0.5664, Val_Acc: 0.8564
# Epoch 195/300, Train_Loss: 0.1389, Train_Acc: 0.9580, Validation Loss: 0.5644, Val_Acc: 0.8597
# Epoch 196/300, Train_Loss: 0.1330, Train_Acc: 0.9605, Validation Loss: 0.6166, Val_Acc: 0.8557
# Epoch 197/300, Train_Loss: 0.1430, Train_Acc: 0.9574, Validation Loss: 0.5891, Val_Acc: 0.8581
# Epoch 198/300, Train_Loss: 0.1461, Train_Acc: 0.9557, Validation Loss: 0.5458, Val_Acc: 0.8598
# Epoch 199/300, Train_Loss: 0.1260, Train_Acc: 0.9634, Validation Loss: 0.5531, Val_Acc: 0.8614
# Epoch 200/300, Train_Loss: 0.1256, Train_Acc: 0.9639, Validation Loss: 0.5630, Val_Acc: 0.8592
# Epoch 201/300, Train_Loss: 0.1296, Train_Acc: 0.9616, Validation Loss: 0.5698, Val_Acc: 0.8593
# Epoch 202/300, Train_Loss: 0.1357, Train_Acc: 0.9596, Validation Loss: 0.5532, Val_Acc: 0.8633
# Epoch 203/300, Train_Loss: 0.1289, Train_Acc: 0.9620, Validation Loss: 0.5834, Val_Acc: 0.8595
# Epoch 204/300, Train_Loss: 0.1269, Train_Acc: 0.9622, Validation Loss: 0.5660, Val_Acc: 0.8608
# Epoch 205/300, Train_Loss: 0.1279, Train_Acc: 0.9626, Validation Loss: 0.6090, Val_Acc: 0.8542
# Epoch 206/300, Train_Loss: 0.1269, Train_Acc: 0.9622, Validation Loss: 0.5837, Val_Acc: 0.8600
# Epoch 207/300, Train_Loss: 0.1299, Train_Acc: 0.9615, Validation Loss: 0.5704, Val_Acc: 0.8607
# Epoch 208/300, Train_Loss: 0.1248, Train_Acc: 0.9634, Validation Loss: 0.6015, Val_Acc: 0.8556
# Epoch 209/300, Train_Loss: 0.1324, Train_Acc: 0.9615, Validation Loss: 0.5798, Val_Acc: 0.8605
# Epoch 210/300, Train_Loss: 0.1272, Train_Acc: 0.9616, Validation Loss: 0.5717, Val_Acc: 0.8566
# Epoch 211/300, Train_Loss: 0.1319, Train_Acc: 0.9606, Validation Loss: 0.5819, Val_Acc: 0.8566
# Epoch 212/300, Train_Loss: 0.1261, Train_Acc: 0.9624, Validation Loss: 0.5687, Val_Acc: 0.8615
# Epoch 213/300, Train_Loss: 0.1214, Train_Acc: 0.9642, Validation Loss: 0.5830, Val_Acc: 0.8575
# Epoch 214/300, Train_Loss: 0.1254, Train_Acc: 0.9635, Validation Loss: 0.5721, Val_Acc: 0.8599
# Epoch 215/300, Train_Loss: 0.1241, Train_Acc: 0.9633, Validation Loss: 0.5797, Val_Acc: 0.8586
# Epoch 216/300, Train_Loss: 0.1215, Train_Acc: 0.9643, Validation Loss: 0.5755, Val_Acc: 0.8602
# Epoch 217/300, Train_Loss: 0.1238, Train_Acc: 0.9633, Validation Loss: 0.5776, Val_Acc: 0.8592
# Epoch 218/300, Train_Loss: 0.1301, Train_Acc: 0.9612, Validation Loss: 0.5803, Val_Acc: 0.8582
# Epoch 219/300, Train_Loss: 0.1243, Train_Acc: 0.9635, Validation Loss: 0.5853, Val_Acc: 0.8581
# Epoch 220/300, Train_Loss: 0.1214, Train_Acc: 0.9637, Validation Loss: 0.6239, Val_Acc: 0.8504
# Epoch 221/300, Train_Loss: 0.1305, Train_Acc: 0.9616, Validation Loss: 0.5902, Val_Acc: 0.8540
# Epoch 222/300, Train_Loss: 0.1178, Train_Acc: 0.9664, Validation Loss: 0.5957, Val_Acc: 0.8583
# Epoch 223/300, Train_Loss: 0.1149, Train_Acc: 0.9672, Validation Loss: 0.5852, Val_Acc: 0.8617
# Epoch 224/300, Train_Loss: 0.1250, Train_Acc: 0.9627, Validation Loss: 0.5969, Val_Acc: 0.8579
# Epoch 225/300, Train_Loss: 0.1182, Train_Acc: 0.9661, Validation Loss: 0.5977, Val_Acc: 0.8561
# Epoch 226/300, Train_Loss: 0.1192, Train_Acc: 0.9647, Validation Loss: 0.5828, Val_Acc: 0.8566
# Epoch 227/300, Train_Loss: 0.1134, Train_Acc: 0.9670, Validation Loss: 0.5828, Val_Acc: 0.8620
# Epoch 228/300, Train_Loss: 0.1211, Train_Acc: 0.9646, Validation Loss: 0.5983, Val_Acc: 0.8591
# Epoch 229/300, Train_Loss: 0.1171, Train_Acc: 0.9656, Validation Loss: 0.6271, Val_Acc: 0.8537
# Epoch 230/300, Train_Loss: 0.1256, Train_Acc: 0.9628, Validation Loss: 0.5890, Val_Acc: 0.8631
# Epoch 231/300, Train_Loss: 0.1103, Train_Acc: 0.9686, Validation Loss: 0.5905, Val_Acc: 0.8606
# Epoch 232/300, Train_Loss: 0.1178, Train_Acc: 0.9653, Validation Loss: 0.6241, Val_Acc: 0.8567
# Epoch 233/300, Train_Loss: 0.1150, Train_Acc: 0.9659, Validation Loss: 0.6042, Val_Acc: 0.8598
# Epoch 234/300, Train_Loss: 0.1161, Train_Acc: 0.9659, Validation Loss: 0.6119, Val_Acc: 0.8547
# Epoch 235/300, Train_Loss: 0.1148, Train_Acc: 0.9662, Validation Loss: 0.5783, Val_Acc: 0.8623
# Epoch 236/300, Train_Loss: 0.1144, Train_Acc: 0.9669, Validation Loss: 0.6060, Val_Acc: 0.8578
# Epoch 237/300, Train_Loss: 0.1201, Train_Acc: 0.9646, Validation Loss: 0.6012, Val_Acc: 0.8600
# Epoch 238/300, Train_Loss: 0.1285, Train_Acc: 0.9613, Validation Loss: 0.6215, Val_Acc: 0.8486
# Epoch 239/300, Train_Loss: 0.1131, Train_Acc: 0.9672, Validation Loss: 0.6035, Val_Acc: 0.8602
# Epoch 240/300, Train_Loss: 0.1113, Train_Acc: 0.9671, Validation Loss: 0.6414, Val_Acc: 0.8480
# Epoch 241/300, Train_Loss: 0.1091, Train_Acc: 0.9682, Validation Loss: 0.6143, Val_Acc: 0.8582
# Epoch 242/300, Train_Loss: 0.1061, Train_Acc: 0.9692, Validation Loss: 0.5974, Val_Acc: 0.8626
# Epoch 243/300, Train_Loss: 0.1149, Train_Acc: 0.9663, Validation Loss: 0.6128, Val_Acc: 0.8616
# Epoch 244/300, Train_Loss: 0.1113, Train_Acc: 0.9679, Validation Loss: 0.6091, Val_Acc: 0.8583
# Epoch 245/300, Train_Loss: 0.1156, Train_Acc: 0.9658, Validation Loss: 0.6034, Val_Acc: 0.8595
# Epoch 246/300, Train_Loss: 0.1121, Train_Acc: 0.9664, Validation Loss: 0.5993, Val_Acc: 0.8601
# Epoch 247/300, Train_Loss: 0.1034, Train_Acc: 0.9700, Validation Loss: 0.6149, Val_Acc: 0.8611
# Epoch 248/300, Train_Loss: 0.1108, Train_Acc: 0.9671, Validation Loss: 0.6089, Val_Acc: 0.8575
# Epoch 249/300, Train_Loss: 0.1150, Train_Acc: 0.9662, Validation Loss: 0.6426, Val_Acc: 0.8508
# Epoch 250/300, Train_Loss: 0.1127, Train_Acc: 0.9661, Validation Loss: 0.6161, Val_Acc: 0.8567
# Epoch 251/300, Train_Loss: 0.1049, Train_Acc: 0.9698, Validation Loss: 0.6207, Val_Acc: 0.8558
# Epoch 252/300, Train_Loss: 0.1045, Train_Acc: 0.9698, Validation Loss: 0.6513, Val_Acc: 0.8500
# Epoch 253/300, Train_Loss: 0.1123, Train_Acc: 0.9668, Validation Loss: 0.6193, Val_Acc: 0.8612
# Epoch 254/300, Train_Loss: 0.1081, Train_Acc: 0.9677, Validation Loss: 0.6413, Val_Acc: 0.8521
# Epoch 255/300, Train_Loss: 0.1084, Train_Acc: 0.9689, Validation Loss: 0.6112, Val_Acc: 0.8618
# Epoch 256/300, Train_Loss: 0.0992, Train_Acc: 0.9716, Validation Loss: 0.6125, Val_Acc: 0.8610
# Epoch 257/300, Train_Loss: 0.1023, Train_Acc: 0.9702, Validation Loss: 0.6312, Val_Acc: 0.8544
# Epoch 258/300, Train_Loss: 0.1082, Train_Acc: 0.9682, Validation Loss: 0.6198, Val_Acc: 0.8578
# Epoch 259/300, Train_Loss: 0.1173, Train_Acc: 0.9652, Validation Loss: 0.5844, Val_Acc: 0.8650
# Epoch 260/300, Train_Loss: 0.1014, Train_Acc: 0.9706, Validation Loss: 0.6134, Val_Acc: 0.8594
# Epoch 261/300, Train_Loss: 0.1051, Train_Acc: 0.9700, Validation Loss: 0.6270, Val_Acc: 0.8583
# Epoch 262/300, Train_Loss: 0.1049, Train_Acc: 0.9693, Validation Loss: 0.6566, Val_Acc: 0.8494
# Epoch 263/300, Train_Loss: 0.1144, Train_Acc: 0.9665, Validation Loss: 0.6099, Val_Acc: 0.8589
# Epoch 264/300, Train_Loss: 0.1003, Train_Acc: 0.9710, Validation Loss: 0.6200, Val_Acc: 0.8595
# Epoch 265/300, Train_Loss: 0.1003, Train_Acc: 0.9712, Validation Loss: 0.6184, Val_Acc: 0.8622
# Epoch 266/300, Train_Loss: 0.0983, Train_Acc: 0.9720, Validation Loss: 0.6344, Val_Acc: 0.8569
# Epoch 267/300, Train_Loss: 0.1119, Train_Acc: 0.9669, Validation Loss: 0.6691, Val_Acc: 0.8486
# Epoch 268/300, Train_Loss: 0.1026, Train_Acc: 0.9706, Validation Loss: 0.6614, Val_Acc: 0.8545
# Epoch 269/300, Train_Loss: 0.1075, Train_Acc: 0.9687, Validation Loss: 0.6329, Val_Acc: 0.8589
# Epoch 270/300, Train_Loss: 0.0967, Train_Acc: 0.9728, Validation Loss: 0.6216, Val_Acc: 0.8605
# Epoch 271/300, Train_Loss: 0.1031, Train_Acc: 0.9706, Validation Loss: 0.6334, Val_Acc: 0.8590
# Epoch 272/300, Train_Loss: 0.1052, Train_Acc: 0.9688, Validation Loss: 0.6446, Val_Acc: 0.8548
# Epoch 273/300, Train_Loss: 0.1008, Train_Acc: 0.9709, Validation Loss: 0.6390, Val_Acc: 0.8563
# Epoch 274/300, Train_Loss: 0.0973, Train_Acc: 0.9728, Validation Loss: 0.6401, Val_Acc: 0.8550
# Epoch 275/300, Train_Loss: 0.1066, Train_Acc: 0.9692, Validation Loss: 0.6276, Val_Acc: 0.8589
# Epoch 276/300, Train_Loss: 0.1021, Train_Acc: 0.9699, Validation Loss: 0.6361, Val_Acc: 0.8591
# Epoch 277/300, Train_Loss: 0.1030, Train_Acc: 0.9694, Validation Loss: 0.6837, Val_Acc: 0.8465
# Epoch 278/300, Train_Loss: 0.0941, Train_Acc: 0.9738, Validation Loss: 0.6461, Val_Acc: 0.8553
# Epoch 279/300, Train_Loss: 0.0972, Train_Acc: 0.9726, Validation Loss: 0.6439, Val_Acc: 0.8538
# Epoch 280/300, Train_Loss: 0.0943, Train_Acc: 0.9732, Validation Loss: 0.6610, Val_Acc: 0.8547
# Epoch 281/300, Train_Loss: 0.0962, Train_Acc: 0.9730, Validation Loss: 0.6453, Val_Acc: 0.8593
# Epoch 282/300, Train_Loss: 0.0960, Train_Acc: 0.9726, Validation Loss: 0.6484, Val_Acc: 0.8571
# Epoch 283/300, Train_Loss: 0.1017, Train_Acc: 0.9708, Validation Loss: 0.6395, Val_Acc: 0.8575
# Epoch 284/300, Train_Loss: 0.1001, Train_Acc: 0.9715, Validation Loss: 0.6354, Val_Acc: 0.8587
# Epoch 285/300, Train_Loss: 0.0874, Train_Acc: 0.9759, Validation Loss: 0.6464, Val_Acc: 0.8566
# Epoch 286/300, Train_Loss: 0.1053, Train_Acc: 0.9686, Validation Loss: 0.6629, Val_Acc: 0.8489
# Epoch 287/300, Train_Loss: 0.0965, Train_Acc: 0.9723, Validation Loss: 0.6506, Val_Acc: 0.8570
# Epoch 288/300, Train_Loss: 0.0893, Train_Acc: 0.9748, Validation Loss: 0.6580, Val_Acc: 0.8592
# Epoch 289/300, Train_Loss: 0.0932, Train_Acc: 0.9736, Validation Loss: 0.6465, Val_Acc: 0.8577
# Epoch 290/300, Train_Loss: 0.0997, Train_Acc: 0.9714, Validation Loss: 0.6585, Val_Acc: 0.8579
# Epoch 291/300, Train_Loss: 0.0931, Train_Acc: 0.9739, Validation Loss: 0.6387, Val_Acc: 0.8587
# Epoch 292/300, Train_Loss: 0.0936, Train_Acc: 0.9735, Validation Loss: 0.6540, Val_Acc: 0.8604
# Epoch 293/300, Train_Loss: 0.0998, Train_Acc: 0.9706, Validation Loss: 0.6445, Val_Acc: 0.8594
# Epoch 294/300, Train_Loss: 0.0922, Train_Acc: 0.9736, Validation Loss: 0.6544, Val_Acc: 0.8574
# Epoch 295/300, Train_Loss: 0.0891, Train_Acc: 0.9741, Validation Loss: 0.6680, Val_Acc: 0.8552
# Epoch 296/300, Train_Loss: 0.0963, Train_Acc: 0.9723, Validation Loss: 0.7399, Val_Acc: 0.8466
# Epoch 297/300, Train_Loss: 0.1049, Train_Acc: 0.9697, Validation Loss: 0.6590, Val_Acc: 0.8570
# Epoch 298/300, Train_Loss: 0.0866, Train_Acc: 0.9755, Validation Loss: 0.6618, Val_Acc: 0.8574
# Epoch 299/300, Train_Loss: 0.0956, Train_Acc: 0.9730, Validation Loss: 0.6435, Val_Acc: 0.8564
# Epoch 300/300, Train_Loss: 0.0933, Train_Acc: 0.9729, Validation Loss: 0.6562, Val_Acc: 0.8553

# %%
import matplotlib.pyplot as plt

plt.plot(train_losses, label='loss')
plt.plot(val_losses, label='val_loss')
plt.xlabel('iteration')
plt.ylabel('Loss')
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(train_acc, label='train_accuracy')
plt.plot(val_acc, label='val_accuracy')
plt.xlabel('iteration')
plt.ylabel('Accuracy')
plt.legend()
